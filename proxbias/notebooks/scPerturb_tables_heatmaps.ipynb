# %% [markdown]
# ## Generate the tables with chromosomal loss information for two of the scPerturb datasets

# %%
from proxbias import scPerturb_processing_plotting as sc
import pandas as pd

# %%
fnames = ["PapalexiSatija2021_eccite_RNA", "FrangiehIzar2021_RNA"]
sc.generate_specific_loss_and_summary_tables(fnames)
# Out:
# FrangiehIzar2021_RNA
# 100% [....................................................................] 1458928348 / 1458928348WARNING: Skipped 5795 genes because they don't have a genomic position annotated.
#   0%|          | 0/44 [00:00<?, ?it/s]
# /Users/safiye.celik/proxbias/proxbias/scPerturb_processing_plotting.py:86: RuntimeWarning: invalid value encountered in divide
#   low_frac = np.sum(cnvarr[:, blocks], axis=1) / len(blocks)

# %% [markdown]
# Let's display Table 1 in the paper. For Table 2, you need to include the CRISPRi datasets ("ReplogleWeissman2022_rpe1", "TianKampmann2021_CRISPRi", "AdamsonWeissman2016_GSM2406681_10X010") in the `fnames` variable above and run `generate_specific_loss_and_summary_tables` for these. Note that ReplogleWeissman2022_rpe1 has thousands of perturbations and it may take hours to run `generate_specific_loss_and_summary_tables` on that dataset.

# %%
allres = pd.read_csv(sc.get_specific_loss_file_path())
display(allres)
# Out:
#    Perturbed gene Perturbation type   Dataset Chr arm Tested loss direction  \
# 0          POU2F2       CRISPR-cas9  Papalexi  chr19q                    3'
# 1           STAT2       CRISPR-cas9  Papalexi  chr12q                    3'
# 2          IFNGR1       CRISPR-cas9  Papalexi   chr6q                    3'
# 3          IFNGR2       CRISPR-cas9  Papalexi  chr21q                    3'
# 4          UBE2L6       CRISPR-cas9  Papalexi  chr11q                    3'
# ..            ...               ...       ...     ...                   ...
# 69           MC1R       CRISPR-cas9  Frangieh  chr16q                    5'
# 70         ATP1A1       CRISPR-cas9  Frangieh   chr1p                    5'
# 71          SMAD4       CRISPR-cas9  Frangieh  chr18q                    5'
# 72          FGFR1       CRISPR-cas9  Frangieh   chr8p                    5'
# 73           DAG1       CRISPR-cas9  Frangieh   chr3p                    5'
#
#     Total # cells  # affected cells  % affected cells Telomeric or centromeric
# 0             661              34.0              5.14                telomeric
# 1             660              31.0              4.69                telomeric
# 2            1342              60.0              4.47                telomeric
# 3            1214              38.0              3.13                telomeric
# 4             518              14.0              2.70                telomeric
# ..            ...               ...               ...                      ...
# 69            726              17.0              2.34              centromeric
# 70             46               1.0              2.13                telomeric
# 71            645              12.0              1.86              centromeric
# 72           1183              20.0              1.69                telomeric
# 73            848              14.0              1.65                telomeric
#
# [74 rows x 9 columns]

# %% [markdown]
# Let's display Table S2 in the paper. Note that since we only included the two CRISPR-cas9 datasets in the `fnames`, the table displayed here will only include these. If you also want to include the CRISPRi datasets, make sure you included them in the `fnames` variable and run `generate_specific_loss_and_summary_tables` for these.

# %%
summres = pd.read_csv(sc.get_specific_loss_summary_file_path())
display(summres)
# Out:
#   Perturbation type   Dataset Tested loss direction  \
# 0       CRISPR-cas9  Frangieh                    3'
# 1       CRISPR-cas9  Frangieh                    5'
# 2       CRISPR-cas9  Papalexi                    3'
# 3       CRISPR-cas9  Papalexi                    5'
#
#    % targets w/ specific loss  Total # tested targets  \
# 0                        12.1                     239
# 1                        14.6                     239
# 2                        32.0                      25
# 3                         8.0                      25
#
#    # targets w/ specific loss  # targets w/ loss towards telomere  \
# 0                          29                                  23
# 1                          35                                  20
# 2                           8                                   6
# 3                           2                                   1
#
#    # targets w/ loss towards centromere
# 0                                     6
# 1                                    15
# 2                                     2
# 3                                     1

# %% [markdown]
# ## Plot the heatmaps for the genes and cells with loss

# %% [markdown]
# Let's generate the heatmaps in Figure 2E-F.

# %%
sc.plot_loss_for_selected_genes(fnames)
# Out:
# WARNING: Skipped 4460 genes because they don't have a genomic position annotated.
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING: Skipped 5795 genes because they don't have a genomic position annotated.
#   0%|          | 0/16 [00:00<?, ?it/s]
